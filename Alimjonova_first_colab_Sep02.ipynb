# %% [markdown]
# <a href="https://colab.research.google.com/github/azizaalimjonova/my-html-site/blob/main/Alimjonova_first_colab_Sep02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Azizakhon Alimjonova September 2, 2026

# %% [markdown]
# # Introduction to DataFrame
#
# # We will use pandas-datastructures and data manipulation tools, in conjuction with numerical computing tools, Numpy

# %%
DataFrame is the primary construct in pandas
A DataFrame is a 2D tables of values
Rows and Columns are indexed

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A','B','C'], index=['X','Y','Z'])
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
 df.tail(2)
# Out:
#    A  B  C
# Y  4  5  6
# Z  7  8  9

# %%
 df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
 df.index
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %% [markdown]
# describe for displaying the basic statistics for the dataset

# %%
 df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %% [markdown]
# # Using pandas library, working with dataset
#
# # Reading a dataset into a DataFrame

# %%
 import pandas as pd
 df=pd.read_csv("https://raw.githubusercontent.com/kimc11/205data/refs/heads/main/mpg.csv")
 df.head()
# Out:
#    Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 0           0  18.0          8         307.0       130.0    3504
# 1           1  15.0          8         350.0       165.0    3693
# 2           2  18.0          8         318.0       150.0    3436
# 3           3  16.0          8         304.0       150.0    3433
# 4           4  17.0          8         302.0       140.0    3449
#
#    acceleration  model_year origin                       name
# 0          12.0          70    usa  chevrolet chevelle malibu
# 1          11.5          70    usa          buick skylark 320
# 2          11.0          70    usa         plymouth satellite
# 3          12.0          70    usa              amc rebel sst
# 4          10.5          70    usa                ford torino

# %%
 df.tail()
# Out:
#      Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 393         393  27.0          4         140.0        86.0    2790
# 394         394  44.0          4          97.0        52.0    2130
# 395         395  32.0          4         135.0        84.0    2295
# 396         396  28.0          4         120.0        79.0    2625
# 397         397  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin             name
# 393          15.6          82     usa  ford mustang gl
# 394          24.6          82  europe        vw pickup
# 395          11.6          82     usa    dodge rampage
# 396          18.6          82     usa      ford ranger
# 397          19.4          82     usa       chevy s-10

# %%
 df.tail(10)
# Out:
#      Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 388         388  26.0          4         156.0        92.0    2585
# 389         389  22.0          6         232.0       112.0    2835
# 390         390  32.0          4         144.0        96.0    2665
# 391         391  36.0          4         135.0        84.0    2370
# 392         392  27.0          4         151.0        90.0    2950
# 393         393  27.0          4         140.0        86.0    2790
# 394         394  44.0          4          97.0        52.0    2130
# 395         395  32.0          4         135.0        84.0    2295
# 396         396  28.0          4         120.0        79.0    2625
# 397         397  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin                        name
# 388          14.5          82     usa  chrysler lebaron medallion
# 389          14.7          82     usa              ford granada l
# ...

# %%
 df.describe()
# Out:
#        Unnamed: 0         mpg   cylinders  displacement  horsepower  \
# count  398.000000  398.000000  398.000000    398.000000  392.000000
# mean   198.500000   23.514573    5.454774    193.425879  104.469388
# std    115.036951    7.815984    1.701004    104.269838   38.491160
# min      0.000000    9.000000    3.000000     68.000000   46.000000
# 25%     99.250000   17.500000    4.000000    104.250000   75.000000
# 50%    198.500000   23.000000    4.000000    148.500000   93.500000
# 75%    297.750000   29.000000    8.000000    262.000000  126.000000
# max    397.000000   46.600000    8.000000    455.000000  230.000000
#
#             weight  acceleration  model_year
# count   398.000000    398.000000  398.000000
# mean   2970.424623     15.568090   76.010050
# std     846.841774      2.757689    3.697627
# min    1613.000000      8.000000   70.000000
# 25%    2223.750000     13.825000   73.000000
# 50%    2803.500000     15.500000   76.000000
# ...

# %%
 df['horsepower'].mean()
# Out:
# np.float64(104.46938775510205)

# %%
 print(df['mpg'].mean())
# Out:
# 23.514572864321607

# %%
 df.columns
# Out:
# Index(['Unnamed: 0', 'mpg', 'cylinders', 'displacement', 'horsepower',
#        'weight', 'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
 df['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
 df['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %% [markdown]
# # Creating a new column
#
# # converting mpg to kilometers per liter

# %%
 df['kpl']=df['mpg']*1.62/3.8
 df.head()
# Out:
#    Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 0           0  18.0          8         307.0       130.0    3504
# 1           1  15.0          8         350.0       165.0    3693
# 2           2  18.0          8         318.0       150.0    3436
# 3           3  16.0          8         304.0       150.0    3433
# 4           4  17.0          8         302.0       140.0    3449
#
#    acceleration  model_year origin                       name       kpl
# 0          12.0          70    usa  chevrolet chevelle malibu  7.673684
# 1          11.5          70    usa          buick skylark 320  6.394737
# 2          11.0          70    usa         plymouth satellite  7.673684
# 3          12.0          70    usa              amc rebel sst  6.821053
# 4          10.5          70    usa                ford torino  7.247368

# %%
 df['mpg'].hist()
# Out:
# <Axes: >

# %%
 df.loc[25:35 , :]
# Out:
#     Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 25          25  10.0          8         360.0       215.0    4615
# 26          26  10.0          8         307.0       200.0    4376
# 27          27  11.0          8         318.0       210.0    4382
# 28          28   9.0          8         304.0       193.0    4732
# 29          29  27.0          4          97.0        88.0    2130
# 30          30  28.0          4         140.0        90.0    2264
# 31          31  25.0          4         113.0        95.0    2228
# 32          32  25.0          4          98.0         NaN    2046
# 33          33  19.0          6         232.0       100.0    2634
# 34          34  16.0          6         225.0       105.0    3439
# 35          35  17.0          6         250.0       100.0    3329
#
#     acceleration  model_year origin                       name        kpl
# 25          14.0          70    usa                  ford f250   4.263158
# ...

# %%
 df.loc[:, 'mpg':'displacement']
# Out:
#       mpg  cylinders  displacement
# 0    18.0          8         307.0
# 1    15.0          8         350.0
# 2    18.0          8         318.0
# 3    16.0          8         304.0
# 4    17.0          8         302.0
# ..    ...        ...           ...
# 393  27.0          4         140.0
# 394  44.0          4          97.0
# 395  32.0          4         135.0
# 396  28.0          4         120.0
# 397  31.0          4         119.0
#
# [398 rows x 3 columns]

# %%
 #Flitering rows based on Boolean condition
 df.loc[df['mpg']>20]
# Out:
#      Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 14           14  24.0          4         113.0        95.0    2372
# 15           15  22.0          6         198.0        95.0    2833
# 17           17  21.0          6         200.0        85.0    2587
# 18           18  27.0          4          97.0        88.0    2130
# 19           19  26.0          4          97.0        46.0    1835
# ..          ...   ...        ...           ...         ...     ...
# 393         393  27.0          4         140.0        86.0    2790
# 394         394  44.0          4          97.0        52.0    2130
# 395         395  32.0          4         135.0        84.0    2295
# 396         396  28.0          4         120.0        79.0    2625
# 397         397  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin                          name        kpl
# 14           15.0          70   japan         toyota corona mark ii  10.231579
# ...

# %%
 df.loc[df['kpl']>8]
# Out:
#      Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 14           14  24.0          4         113.0        95.0    2372
# 15           15  22.0          6         198.0        95.0    2833
# 17           17  21.0          6         200.0        85.0    2587
# 18           18  27.0          4          97.0        88.0    2130
# 19           19  26.0          4          97.0        46.0    1835
# ..          ...   ...        ...           ...         ...     ...
# 393         393  27.0          4         140.0        86.0    2790
# 394         394  44.0          4          97.0        52.0    2130
# 395         395  32.0          4         135.0        84.0    2295
# 396         396  28.0          4         120.0        79.0    2625
# 397         397  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin                          name        kpl
# 14           15.0          70   japan         toyota corona mark ii  10.231579
# ...

# %%
 df.loc[df['mpg']>20, 'name']
# Out:
# 14            toyota corona mark ii
# 15                  plymouth duster
# 17                    ford maverick
# 18                     datsun pl510
# 19     volkswagen 1131 deluxe sedan
#                    ...
# 393                 ford mustang gl
# 394                       vw pickup
# 395                   dodge rampage
# 396                     ford ranger
# 397                      chevy s-10
# Name: name, Length: 238, dtype: object

# %%
 df.loc[df['mpg']>20, ['name','mpg']]
# Out:
#                              name   mpg
# 14          toyota corona mark ii  24.0
# 15                plymouth duster  22.0
# 17                  ford maverick  21.0
# 18                   datsun pl510  27.0
# 19   volkswagen 1131 deluxe sedan  26.0
# ..                            ...   ...
# 393               ford mustang gl  27.0
# 394                     vw pickup  44.0
# 395                 dodge rampage  32.0
# 396                   ford ranger  28.0
# 397                    chevy s-10  31.0
#
# [238 rows x 2 columns]

# %% [markdown]
# # Aggregating data:groupby
#
# # Find the average mpg by country of origin

# %%
 df_grouped=df['mpg'].groupby(df['origin'])
 df_grouped.mean()
# Out:
# origin
# europe    27.891429
# japan     30.450633
# usa       20.083534
# Name: mpg, dtype: float64

# %%
 df_grouped=df['mpg'].groupby(df['model_year'])
 df_grouped.mean()
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %% [markdown]
# #My homework starts here
#
# #Read the data file

# %%
import pandas as pd
df=pd.read_csv ("https://raw.githubusercontent.com/kimc11/205data/refs/heads/main/movies_imdb.csv")
df.head()
# Out:
#    Unnamed: 0      director_name  duration  director_facebook_likes  \
# 0           0      James Cameron     178.0                      0.0
# 1           1     Gore Verbinski     169.0                    563.0
# 2           2         Sam Mendes     148.0                      0.0
# 3           3  Christopher Nolan     164.0                  22000.0
# 4           4        Doug Walker       NaN                    131.0
#
#    actor_1_facebook_likes        gross     actor_1_name  \
# 0                  1000.0  760505847.0      CCH Pounder
# 1                 40000.0  309404152.0      Johnny Depp
# 2                 11000.0  200074175.0  Christoph Waltz
# 3                 27000.0  448130642.0        Tom Hardy
# 4                   131.0          NaN      Doug Walker
#
#                                   movie_title  facenumber_in_poster  \
# 0                                      Avatar                   0.0
# 1    Pirates of the Caribbean: At World's End                   0.0
# ...

# %%
df[['director_name','movie_title','duration']].head(20)
# Out:
#         director_name                                  movie_title  duration
# 0       James Cameron                                       Avatar     178.0
# 1      Gore Verbinski     Pirates of the Caribbean: At World's End     169.0
# 2          Sam Mendes                                      Spectre     148.0
# 3   Christopher Nolan                        The Dark Knight Rises     164.0
# 4         Doug Walker   Star Wars: Episode VII - The Force Awakens       NaN
# 5      Andrew Stanton                                  John Carter     132.0
# 6           Sam Raimi                                 Spider-Man 3     156.0
# 7        Nathan Greno                                      Tangled     100.0
# 8         Joss Whedon                      Avengers: Age of Ultron     141.0
# 9         David Yates       Harry Potter and the Half-Blood Prince     153.0
# 10        Zack Snyder           Batman v Superman: Dawn of Justice     183.0
# ...

# %% [markdown]
# Shows the director, movie title, and duration for the first 20 movies.

# %%
df[df['director_name']=='Christopher Nolan'][['movie_title','title_year','gross']]
# Out:
#                 movie_title  title_year        gross
# 3     The Dark Knight Rises      2012.0  448130642.0
# 66          The Dark Knight      2008.0  533316061.0
# 96             Interstellar      2014.0  187991439.0
# 97                Inception      2010.0  292568851.0
# 120           Batman Begins      2005.0  205343774.0
# 1057               Insomnia      2002.0   67263182.0
# 1222           The Prestige      2006.0   53082743.0
# 3646                Memento      2000.0   25530884.0

# %% [markdown]
# Shows Christopher Nolans movies, their release years, and gross earnings.

# %%
df[df['director_name']=='Christopher Nolan']['gross'].sum()
# Out:
# np.float64(1813227576.0)

# %% [markdown]
# Calculates the total gross earnings of Christopher Nolans movies.

# %%
df.groupby('genre')['duration'].mean()
# Out:
# genre
# Action         110.676577
# Adventure      106.482916
# Animation       82.229508
# Biography      125.412000
# Comedy          99.498090
# Crime          112.032544
# Documentary     93.204819
# Drama          113.164544
# Family          96.454545
# Fantasy        101.042553
# Film-Noir       95.000000
# Game-Show       60.000000
# History         90.000000
# Horror          96.574661
# Music           93.000000
# Musical        103.750000
# Mystery        107.531250
# Romance         85.500000
# Sci-Fi         100.076923
# Thriller       103.666667
# Western        106.000000
# Name: duration, dtype: float64

# %% [markdown]
# Calculates the average movie duration for each genre.
